# %% [markdown]
# # plot examples
# source: https://towardsdatascience.com/making-plots-in-jupyter-notebook-beautiful-more-meaningful-23c8a35c0d5d

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,7,100)
y1 = np.sin(x)
y2 = np.cos(x)
line1, = plt.plot(x, y1, label = 'sin')
line2, = plt.plot(x, y2, label = 'cos')
plt.xlim(-1, 6)
plt.ylim(-1.5, 1.5)
plt.xlabel('time (s)', fontsize = 15)
plt.ylabel('magnitude (units)', fontsize = 15)
plt.legend(handles = [line1, line2], loc = 'lower right')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 5, 0, 20])
plt.xlabel('time (s)', fontsize = 15)
plt.ylabel('distance (m)', fontsize = 15)
plt.title('This is a simple example', fontsize = 25)
plt.grid()
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, 20*t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.grid()
plt.show()

# %%
names = ['A1', 'A2', 'A3', 'A4']
values = [1, 15, 90, 200]

plt.figure(figsize=(16, 4))

plt.subplot(141)
plt.bar(names, values)
plt.subplot(142)
plt.scatter(names, values)
plt.subplot(143)
plt.plot(names, values)
plt.subplot(144)
plt.bar(names, values)
plt.suptitle('Categorical Plotting')
plt.show()
